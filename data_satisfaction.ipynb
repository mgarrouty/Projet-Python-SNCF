# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 1.6 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_excel('satisfaction_sept2021.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1          Unnamed: 2            Unnamed: 3  \
# 0         NaN        NaN                 NaN                   NaN
# 1         DRG         UG                Gare  Typologie de la gare
# 2  Toutes DRG  Toutes UG             Gares A                   NaN
# 3  Toutes DRG  Toutes UG  Gares A - 36 gares                   NaN
# 4  Toutes DRG  Toutes UG  Gares A - 24 gares                   NaN
#
#                Unnamed: 4 Unnamed: 5           Unnamed: 6    Unnamed: 7  \
# 0                     NaN        NaN                  NaN           NaN
# 1  Segmentation marketing   Code UIC  Typologie de client          Zone
# 2                    Tous        NaN    Toutes typologies  Toutes zones
# 3                    Tous        NaN    Toutes typologies  Toutes zones
# 4                    Tous        NaN    Toutes typologies  Toutes zones
#
#           Unnamed: 8              Unnamed: 9  ...         Unnamed: 77  \
# ...
